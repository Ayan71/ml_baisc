# %%
**********************************************PANDAS NOTES*********************************************************************


PANDAS IS A PYTHON LIBRARY USES FOR WORKING ANYLYSIS THE DATA ,DATA MANUPULATION CREATED BY' MC TINNEY 2008'
IN HAS FUNCTION FOR ANALYSIS CLEANING EXPLORING AND MANUPULATING DATA ! the name pandas has a refrece to both 'panel data '
FIRSTLY SERIES SECONDLY DATAFRAME

# %%
import pandas as pd

# %%
#firstly data save and file save same loaction then read the file 
df=pd.read_csv('housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# give the top five data
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# give the lowest top five data in afaom of table 
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
# shpe it is use firstlyt give the columns shape then row shapes
df.shape
# Out:
# (545, 13)

# %%
# describe it is use to give the value like mean,std,min,max,% etc
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# info give the data of foam of non-null and null foam
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
#columns give the name what thew name of columns in the foam of array
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
#values use tro give only values like columns of values in the foam of array
df.values
# Out:
# array([[13300000, 7420, 4, ..., 2, 'yes', 'furnished'],
#        [12250000, 8960, 4, ..., 3, 'no', 'furnished'],
#        [12250000, 9960, 3, ..., 2, 'yes', 'semi-furnished'],
#        ...,
#        [1750000, 3620, 2, ..., 0, 'no', 'unfurnished'],
#        [1750000, 2910, 3, ..., 0, 'no', 'furnished'],
#        [1750000, 3850, 3, ..., 0, 'no', 'unfurnished']], dtype=object)

# %%
# u give only one column name then output show area of the housing total data 
#this is foam of series
df.area
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
#this is foam of dataframe
#give the name of column only perticlular data show
df[['area','price']]
# Out:
#      area     price
# 0    7420  13300000
# 1    8960  12250000
# 2    9960  12250000
# 3    7500  12215000
# 4    7420  11410000
# ..    ...       ...
# 540  3000   1820000
# 541  2400   1767150
# 542  3620   1750000
# 543  2910   1750000
# 544  3850   1750000
#
# [545 rows x 2 columns]

# %%
#  start and end un give the data
df[2:7]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
# 5  10850000  7500         3          3        1      yes        no      yes
# 6  10150000  8580         4          3        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# 5              no             yes        2      yes   semi-furnished
# 6              no             yes        2      yes   semi-furnished

# %%
#u want data ascending & desending order then use this 

df.sort_values(by='area',ascending=False)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 413   3430000   1950         3          2        2      yes        no
# 271   4340000   1905         5          1        2       no        no
# 527   2275000   1836         2          1        1       no        no
# 537   1890000   1700         3          1        2      yes        no
# 449   3150000   1650         3          1        2       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
#apply-apply function iterates whole column an series lambda function perfoam operation and retrun values to apply and stores it into data frame
df.price=df.price.apply(lambda x:x*75)
df.price
# Out:
# 0      997500000
# 1      918750000
# 2      918750000
# 3      916125000
# 4      855750000
#          ...
# 540    136500000
# 541    132536250
# 542    131250000
# 543    131250000
# 544    131250000
# Name: price, Length: 545, dtype: int64

# %%
#iloc it is without labell it taken meaningfull column names as index
#first give the values of column then row
df.iloc[2:9,1:5]
# Out:
#     area  bedrooms  bathrooms  stories
# 2   9960         3          2        2
# 3   7500         4          2        2
# 4   7420         4          1        2
# 5   7500         3          3        1
# 6   8580         4          3        4
# 7  16200         5          3        2
# 8   8100         4          1        2

# %%
#it will give row of indexs 1,54,67,8
df.iloc[[1,54,67,8]]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 1   918750000  8960         4          4        4      yes        no       no
# 54  551250000  6000         3          2        2      yes       yes       no
# 67  517125000  7700         3          2        1      yes        no       no
# 8   740250000  8100         4          1        2      yes       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 1               no             yes        3       no        furnished
# 54              no             yes        1       no   semi-furnished
# 67              no              no        2       no      unfurnished
# 8               no             yes        2      yes        furnished

# %%
# firstly start and and the range then operation add only divided 2 ==0 then it print else not print 
df.iloc[[x for x in range(50)if x%2==0]]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0   997500000   7420         4          2        3      yes        no
# 2   918750000   9960         3          2        2      yes        no
# 4   855750000   7420         4          1        2      yes       yes
# 6   761250000   8580         4          3        4      yes        no
# 8   740250000   8100         4          1        2      yes       yes
# 10  735000000  13200         3          1        2      yes        no
# 12  698250000   6550         4          2        2      yes        no
# 14  693000000   7800         3          2        2      yes        no
# 16  682500000   6600         4          2        2      yes       yes
# 18  666750000   4600         3          2        2      yes       yes
# 20  656250000   4320         3          1        2      yes        no
# 22  648375000   8050         3          1        1      yes       yes
# ...

# %%
#loc is a label data it is lable based slicing it use column name as parameter 
#fistly u give the range start and end then give the name of columns 
#it we give two return data frame if we give one it return series
df.loc[2:5,['area','price']]
# Out:
#    area      price
# 2  9960  918750000
# 3  7500  916125000
# 4  7420  855750000
# 5  7500  813750000

# %%
# apply logical operation what u want 4 bedrooms then u apply this types 
df[(df.bedrooms>4)&(df.guestroom=='yes')]
# Out:
#          price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 34   609000000  6840         5          1        2      yes       yes
# 152  417375000  5400         5          1        2      yes       yes
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 34       yes              no             yes        1       no
# 152      yes              no             yes        0      yes
#
#     furnishingstatus
# 34         furnished
# 152        furnished

# %%
# it takes a dictonary by which it uses to change the iteams in columns 
df.mainroad=df['mainroad'].map({'yes':1,'no':0})
df.mainroad
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 540   NaN
# 541   NaN
# 542   NaN
# 543   NaN
# 544   NaN
# Name: mainroad, Length: 545, dtype: float64

# %%
# if give unique values of a particular column
df.area.unique()
# Out:
# array([ 7420,  8960,  9960,  7500,  8580, 16200,  8100,  5750, 13200,
#         6000,  6550,  3500,  7800,  6600,  8500,  4600,  6420,  4320,
#         7155,  8050,  4560,  8800,  6540,  8875,  7950,  5500,  7475,
#         7000,  4880,  5960,  6840,  7482,  9000,  6360,  6480,  4300,
#         7440,  6325,  5150, 11440,  7680,  8880,  6240, 11175,  7700,
#        12090,  4000,  5020,  4040,  4260,  6500,  5700, 10500,  3760,
#         8250,  6670,  3960,  7410,  5000,  6750,  4800,  7200,  4100,
#         6400,  6350,  4500,  5450,  3240,  6615,  8372,  9620,  6800,
#         8000,  6900,  3700,  7020,  7231,  6254,  7320,  6525, 15600,
#         7160, 11460,  5828,  5200,  5400,  4640,  5800,  6660,  4700,
#         5136,  4400,  3300,  3650,  6100,  2817,  7980,  3150,  6210,
#         6825,  6710,  6450, 10269,  8400,  5300,  3800,  9800,  8520,
#         6050,  7085,  3180,  3410,  3000, 11410,  5720,  3540,  7600,
# ...

# %%
df.price.unique()
# Out:
# array([997500000, 918750000, 916125000, 855750000, 813750000, 761250000,
#        740250000, 735000000, 726075000, 698250000, 693000000, 682500000,
#        672000000, 666750000, 664125000, 656250000, 651000000, 648375000,
#        643125000, 640500000, 634725000, 630000000, 622125000, 614250000,
#        609000000, 606070500, 603225000, 598500000, 597187500, 593250000,
#        590625000, 588000000, 577500000, 567000000, 564375000, 561750000,
#        559125000, 556500000, 551250000, 550725000, 543375000, 540750000,
#        535500000, 530250000, 527625000, 525000000, 519750000, 517125000,
#        514500000, 509250000, 506625000, 504000000, 501375000, 498750000,
#        497175000, 496125000, 493500000, 488250000, 485625000, 483000000,
#        481425000, 480375000, 472500000, 471975000, 469875000, 467250000,
#        464625000, 462000000, 459375000, 458062500, 456750000, 456225000,
#        451500000, 446250000, 445725000, 441000000, 440475000, 439950000,
# ...

# %%
#it is sum to create specific groups according to the given columns values we can created group using single columns or multiple columns

df.groupby(['area'])['bathrooms'].sum()
# Out:
# area
# 1650     1
# 1700     1
# 1836     1
# 1905     1
# 1950     3
#         ..
# 12900    1
# 12944    1
# 13200    2
# 15600    1
# 16200    3
# Name: bathrooms, Length: 284, dtype: int64

# %%
# new column to be added to data frame 
df['emty']=df.bedrooms
df['emty']
# Out:
# 0      4
# 1      4
# 2      3
# 3      4
# 4      4
#       ..
# 540    2
# 541    3
# 542    2
# 543    3
# 544    3
# Name: emty, Length: 545, dtype: int64

# %%
# pivot table it is an alternate of group  by function but simple then  it group of given column with all values
#index,values,agg fun,columns                                                                                                                                                                                                                                                          
df.pivot_table(index=['area','price'],values=['parking','bathrooms'])
# Out:
#                  bathrooms  parking
# area  price
# 1650  236250000        1.0      0.0
# 1700  141750000        1.0      0.0
# 1836  170625000        1.0      0.0
# 1905  325500000        1.0      0.0
# 1950  168000000        1.0      0.0
# ...                    ...      ...
# 12944 262500000        1.0      0.0
# 13200 519750000        1.0      1.0
#       735000000        1.0      2.0
# 15600 445725000        1.0      2.0
# 16200 761250000        3.0      0.0
#
# [532 rows x 2 columns]

# %%
df['area'].agg
# Out:
# <bound method Series.aggregate of 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64>

# %%
#aggregate it is use to give the name of column then what u want mwan ,median ,mode then operation use 
df['price'].agg('mode')
# Out:
# 0    262500000
# 1    315000000
# dtype: int64

# %%
#series are 1d array stucture which in contain non numeric data it is date ,time,boolean series the part of the data frame 
l1=[1,2,3,4,5]
s1=pd.Series(l1)
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1=pd.Series([1,2,3,3])
s1.dtype
# Out:
# dtype('int64')

# %%
pd.Series({'a':10,'b':20,'c':30})
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series({'a':10})
# Out:
# a    10
# dtype: int64

# %%
# DATA FRAME IS TABLE WITH ROW AND COLUMN WHERE ROW AND INDEX AND COLUMN AS MININGFULL NAME DATA FRAME CAN BE BUILT FROM DICNANARY JSOM OBJECT READING CSV FILES 
pd.DataFrame({"name":['bob','sam','karan'],"MARKS":[22,43,444],"CLASS":[6,8,10]})
# Out:
#     name  MARKS  CLASS
# 0    bob     22      6
# 1    sam     43      8
# 2  karan    444     10
